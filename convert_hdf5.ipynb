# %% [markdown]
# # Checking the file's structure

# %%
# this code displays all keys within the file and their class

import h5py

hdf5_file = 'koennadoen.h5'
with h5py.File(hdf5_file, 'r') as file:
    def print_structure(name, obj):
        print(f"{name}: {type(obj)}")

    file.visititems(print_structure)
# Out:
# Acquisition.1: <class 'h5py._hl.group.Group'>
# Acquisition.1/Segment.1.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.1/Segment.1.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.1/Segment.1.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.1/Segment.1.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.10: <class 'h5py._hl.group.Group'>
# Acquisition.10/Segment.10.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.10/Segment.10.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.10/Segment.10.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.10/Segment.10.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.100: <class 'h5py._hl.group.Group'>
# Acquisition.100/Segment.100.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.100/Segment.100.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.100/Segment.100.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.100/Segment.100.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.11: <class 'h5py._hl.group.Group'>
# Acquisition.11/Segment.11.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.11/Segment.11.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.11/Segment.11.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.11/Segment.11.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.12: <class 'h5py._hl.group.Group'>
# Acquisition.12/Segment.12.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.12/Segment.12.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.12/Segment.12.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.12/Segment.12.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.13: <class 'h5py._hl.group.Group'>
# Acquisition.13/Segment.13.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.13/Segment.13.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.13/Segment.13.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.13/Segment.13.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.14: <class 'h5py._hl.group.Group'>
# Acquisition.14/Segment.14.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.14/Segment.14.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.14/Segment.14.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.14/Segment.14.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.15: <class 'h5py._hl.group.Group'>
# Acquisition.15/Segment.15.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.15/Segment.15.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.15/Segment.15.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.15/Segment.15.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.16: <class 'h5py._hl.group.Group'>
# Acquisition.16/Segment.16.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.16/Segment.16.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.16/Segment.16.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.16/Segment.16.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.17: <class 'h5py._hl.group.Group'>
# Acquisition.17/Segment.17.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.17/Segment.17.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.17/Segment.17.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.17/Segment.17.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.18: <class 'h5py._hl.group.Group'>
# Acquisition.18/Segment.18.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.18/Segment.18.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.18/Segment.18.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.18/Segment.18.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.19: <class 'h5py._hl.group.Group'>
# Acquisition.19/Segment.19.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.19/Segment.19.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.19/Segment.19.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.19/Segment.19.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.2: <class 'h5py._hl.group.Group'>
# Acquisition.2/Segment.2.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.2/Segment.2.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.2/Segment.2.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.2/Segment.2.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.20: <class 'h5py._hl.group.Group'>
# Acquisition.20/Segment.20.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.20/Segment.20.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.20/Segment.20.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.20/Segment.20.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.21: <class 'h5py._hl.group.Group'>
# Acquisition.21/Segment.21.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.21/Segment.21.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.21/Segment.21.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.21/Segment.21.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.22: <class 'h5py._hl.group.Group'>
# Acquisition.22/Segment.22.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.22/Segment.22.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.22/Segment.22.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.22/Segment.22.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.23: <class 'h5py._hl.group.Group'>
# Acquisition.23/Segment.23.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.23/Segment.23.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.23/Segment.23.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.23/Segment.23.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.24: <class 'h5py._hl.group.Group'>
# Acquisition.24/Segment.24.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.24/Segment.24.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.24/Segment.24.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.24/Segment.24.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.25: <class 'h5py._hl.group.Group'>
# Acquisition.25/Segment.25.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.25/Segment.25.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.25/Segment.25.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.25/Segment.25.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.26: <class 'h5py._hl.group.Group'>
# Acquisition.26/Segment.26.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.26/Segment.26.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.26/Segment.26.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.26/Segment.26.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.27: <class 'h5py._hl.group.Group'>
# Acquisition.27/Segment.27.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.27/Segment.27.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.27/Segment.27.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.27/Segment.27.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.28: <class 'h5py._hl.group.Group'>
# Acquisition.28/Segment.28.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.28/Segment.28.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.28/Segment.28.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.28/Segment.28.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.29: <class 'h5py._hl.group.Group'>
# Acquisition.29/Segment.29.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.29/Segment.29.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition
ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.97: <class 'h5py._hl.group.Group'>
# Acquisition.97/Segment.97.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.97/Segment.97.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.97/Segment.97.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.97/Segment.97.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.98: <class 'h5py._hl.group.Group'>
# Acquisition.98/Segment.98.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.98/Segment.98.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.98/Segment.98.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.98/Segment.98.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.99: <class 'h5py._hl.group.Group'>
# Acquisition.99/Segment.99.ch1.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.99/Segment.99.ch2.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.99/Segment.99.ch3.0: <class 'h5py._hl.dataset.Dataset'>
# Acquisition.99/Segment.99.ch4.0: <class 'h5py._hl.dataset.Dataset'>
# Header: <class 'h5py._hl.group.Group'>
# Header/Instrument: <class 'h5py._hl.group.Group'>
# Header/Instrument/Channel.ch1: <class 'h5py._hl.group.Group'>
# Header/Instrument/Channel.ch2: <class 'h5py._hl.group.Group'>
# Header/Instrument/Channel.ch3: <class 'h5py._hl.group.Group'>
# Header/Instrument/Channel.ch4: <class 'h5py._hl.group.Group'>
# Header/RunParameters: <class 'h5py._hl.group.Group'>

# %% [markdown]
# # Converting the data

# %%
import h5py
import pandas as pd
import numpy as np

# open the HDF5 file
hdf5_file_path = '25-55-OR.h5'

csv_file_path = 'output' + hdf5_file_path[:-3] + '.csv'

data_records = []

# function to extract data from the datasets
def extract_data_from_group(group_name, group):
    '''Extract and flatten the data from a group's keys '''
    for key in group.keys():
        dataset = group[key]
        if isinstance(dataset, h5py.Dataset):
            # flatten the dataset if it has more than 1 dimension
            flat_data = dataset[()].flatten()
            data_records.append({
                'Group': group_name,
                'Dataset': key,
                'Data': flat_data
            })

# iterate through each acquisition group and extract their data
with h5py.File(hdf5_file_path, 'r') as f:
    for acquisition_name in f.keys():
        acquisition_group = f[acquisition_name]
        if isinstance(acquisition_group, h5py.Group):
            extract_data_from_group(acquisition_name, acquisition_group)

# convert the records to a pandas dataframe
df = pd.DataFrame(data_records)

# expand the 'Data' field into separate columns
data_expanded = pd.DataFrame(df['Data'].tolist())
df = pd.concat([df.drop('Data', axis=1), data_expanded], axis=1)

# save to csv
df.to_csv(csv_file_path, index=False)

print(f"Data successfully written to {csv_file_path}.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 31
#      29         acquisition_group = f[acquisition_name]
#      30         if isinstance(acquisition_group, h5py.Group):
# ---> 31             extract_data_from_group(acquisition_name, acquisition_group)
#      33 # convert the records to a pandas dataframe
#      34 df = pd.DataFrame(data_records)
#
# Cell In[2], line 19, in extract_data_from_group(group_name, group)
#      16 dataset = group[key]
#      17 if isinstance(dataset, h5py.Dataset):
#      18     # flatten the dataset if it has more than 1 dimension
# ---> 19     flat_data = dataset[()].flatten()
#      20     data_records.append({
#      21         'Group': group_name,
#      22         'Dataset': key,
#      23         'Data': flat_data
#      24     })
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File c:\Users\rutge\anaconda3\Lib\site-packages\h5py\_hl\dataset.py:742, in Dataset.__getitem__(self, args, new_dtype)
#     736     """Is this dataset suitable for simple reading"""
#     737     return (
#     738         self._extent_type == h5s.SIMPLE
#     739         and isinstance(self.id.get_type(), (h5t.TypeIntegerID, h5t.TypeFloatID))
#     740     )
# --> 742 @with_phil
#     743 def __getitem__(self, args, new_dtype=None):
#     744     """ Read a slice from the HDF5 dataset.
#     745
#     746     Takes slices and recarray-style field names (more than one is
#    (...)
#     752     * Boolean "mask" array indexing
#     753     """
#     754     args = args if isinstance(args, tuple) else (args,)
#
# KeyboardInterrupt:
